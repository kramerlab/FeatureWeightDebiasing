# %%
from ucimlrepo import fetch_ucirepo
import numpy as np

# %%
cdc_diabetes_health_indicators = fetch_ucirepo(id=891)

# %%
cdc_diabetes_health_indicators
diabetes_X = cdc_diabetes_health_indicators.data.features 
diabetes_y = cdc_diabetes_health_indicators.data.targets

# %%
print(len(diabetes_y))
print(np.sum(diabetes_y == 0))
print(np.sum(diabetes_y == 1))
print(len(diabetes_X.columns))

# %%
diabetes_X.to_csv("diabetes_X.csv", index=False)
diabetes_y.to_csv("diabetes_y.csv", index=False)

# %%
bank_marketing = fetch_ucirepo(id=222)
bank_marketing_X = bank_marketing.data.features 
bank_marketing_y = bank_marketing.data.targets

# %%
print(len(bank_marketing_y))
print(np.sum(bank_marketing_y == "no"))
print(np.sum(bank_marketing_y == "yes"))
print(len(bank_marketing_X.columns))

# %%
bank_marketing_X.to_csv("bank_marketing_X.csv", index=False)
bank_marketing_y.to_csv("bank_marketing_y.csv", index=False)

# %%
statlog_german_credit_data = fetch_ucirepo(id=144)
german_credit_X = statlog_german_credit_data.data.features 
german_credit_y = statlog_german_credit_data.data.targets 
german_credit_X.to_csv("german_credit_X.csv", index=False)
german_credit_y.to_csv("german_credit_y.csv", index=False)

# %%
german_credit_y

# %%
print(len(german_credit_y))
print(np.sum(german_credit_y == 1))
print(np.sum(german_credit_y == 2))
print(len(german_credit_X.columns))
