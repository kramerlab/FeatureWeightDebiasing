# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from src.utils.data_loader import load_breast_cancer_data, load_folktables_income_data, load_loan_prediction
import numpy as np
np.random.seed(5)
from src.utils.sampling import sample
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
from src.utils.metrics import compute_test_metrics_mrs, train_classifier_auroc_feature_weighted

# %%
df, columns, target = load_breast_cancer_data()

# %%
df[columns] = StandardScaler().fit_transform(df[columns])

# %%
N, R = sample(
            "mean_difference",
            df,
            target,
            train_fraction=0.5,
            bias_fraction=0.75,
            columns=columns,
        )

# %%
import pandas as pd
from sklearn.inspection import permutation_importance
feature_weights = np.ones(len(columns))
clf, auroc = train_classifier_auroc_feature_weighted(N, R, columns, feature_weights=feature_weights, draw_with_feature_weights=True, 
                          class_weight="balanced", random_state=0, splitter="feature_weighted_best", max_features=None)
print(auroc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 from sklearn.inspection import permutation_importance
# ----> 3 feature_weights = np.ones(len(columns))
#       4 clf, auroc = train_classifier_auroc_feature_weighted(N, R, columns, feature_weights=feature_weights, draw_with_feature_weights=True,
#       5                           class_weight="balanced", random_state=0, splitter="feature_weighted_best", max_features=None)
#       6 print(auroc)
#
# NameError: name 'np' is not defined
