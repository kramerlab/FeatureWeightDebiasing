# %%
import pandas as pd
from pathlib import Path

# %%
result_path = Path("../results/")
methods = ["logistic_regression", "mutual_information", "random", "random_forest", "uniform"]
datasets = ["breast_cancer", "folktables_employment", "folktables_income", "hr_analytics", "loan_prediction"]
bias_types = ["less_negative_class", "less_positive_class", "mean_difference"]
metrics = ["MMDs", ]

# %%
data = []
for dataset in datasets:
    for bias_type in bias_types:
        for method in methods:
            json = pd.read_json(str(result_path / method / "downstream" / dataset / bias_type / "results.json"))
            mmd = [dataset, bias_type, method, json["MMDs"]["mean"]]
            data.append(mmd)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 for bias_type in bias_types:
#       4     for method in methods:
# ----> 5         json = pd.read_json(str(result_path / method / "downstream" / dataset / bias_type / "results.json"))
#       6         mmd = [dataset, bias_type, method, json["MMDs"]["mean"]]
#       7         data.append(mmd)
#
# File ~/.virtualenvs/feature_weighting/lib/python3.10/site-packages/pandas/io/json/_json.py:780, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     777 if convert_axes is None and orient != "table":
#     778     convert_axes = True
# --> 780 json_reader = JsonReader(
#     781     path_or_buf,
#     782     orient=orient,
# ...

# %%
data_frame = pd.DataFrame(data=data, columns=["Dataset", "Bias Type", "Method", "Mean MMD"])

# %%
bias_type = "less_negative_class"
data_frame[data_frame["Bias Type"] == bias_type]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 bias_type = "less_negative_class"
# ----> 2 data_frame[data_frame["Bias Type"] == bias_type]
#
# NameError: name 'data_frame' is not defined
